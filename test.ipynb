# %%
import json
import os
import re

from gliner import GLiNER

# %%
model = GLiNER.from_pretrained("urchade/gliner_small")
# Out:
# Fetching 4 files: 100%|██████████| 4/4 [00:00<00:00, 14413.42it/s]
# /home/erikn/code/projects/PREPARE/medical-term-extraction/venv/lib/python3.10/site-packages/transformers/convert_slow_tokenizer.py:558: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
def tokenize_text(text):
    """Tokenize the input text into a list of tokens."""
    return re.findall(r"\w+(?:[-_]\w+)*|\S", text)

# %%
with open("./data/interim/maccrobat2020.json", "r", encoding="utf8") as f:
    data = json.load(f)

# %%
example = data[0]

# %%
example
# Out:
# {'text': "A 48-year-old man presented at our hospital complaining of intracranial bruits.\nThe cranial nerve and laboratory examinations were normal.\nA DVAF was considered, conventional digital subtraction angiography was performed, which showed a Cognard II DVAF in the location of right hypoglossal canal (HC).\nThe DVAF was fed by the meningeal branches of the bilateral ascending pharyngeal arteries, and the right anterior condylar veins within the hypoglossal canal that was the fistulous point mainly drained into the jugular vein.\nEndovascular treatment was insisted upon by the patient because of the associated intolerable intracranial bruit.\nTreatment was performed by transarterial approach under general anesthesia using a biplane angiographic unit.\nStandard coaxial techniques were used.\nThe guide catheter was navigated into the left ascendingtrawt pharyngeal artery.\nMarathon flow directed catheter (eV3) was subsequently navigated over a Mirage.008 microwire (eV3) to reach as near as possible to the fistula.\nThe microcatheter was flushed with 10 mL of normal saline.\nThe dead space of the microcatheter was subsequently filled with dimethyl sulfoxide (DMSO).\nOnyx-18 was then injected over two minutes to fill the microcatheter and to replace the DMSO in the dead space.\nThe injection was stopped until unwanted flow into branches of the right ascending pharyngeal artery was observed.\nThe follow-up angiogram showed no residual shunt (Figure \u200b1).\nThe intracranial bruits disappeared immediately after the operation.\nFor the toxicity of DMSO, 10 mg dexamethasone was intravenously injected for three days.\nOn the second day after endovascular treatment, the patient complainted of difficulty moving his tongue to the left.\nCranial nerve examination was only significant for a right hypoglossal nerve palsy.\nThe patient was discharged from our hospital four days after treatment without continuative pharmacotherapy.\nAt two months follow-up, the patient's main complaint were difficulty swallowing (dysphagia) and slurred speech (dysarthria).\nIn addition, his tongue deviated toward the right during tongue protrusion, and marked right-sided hemiatrophy was observed (Figure \u200b2).\nThe cranial nerve examation showed right hypoglossal nerve palsy persisted.\nWe telephone the patient at three months follow-up and requested a vocal cord evaluation by an ENT specialist in a local hospital.\nVocal cord paralysis was not found, and there was no evidence of vagus nerve dysfunction.\nOral Vitamin B12 was used and his prognosis was still at a long follow-up.\n",
#  'entities': [{'label': 'age', 'start': 2, 'end': 13, 'text': '48-year-old'},
#   {'label': 'sex', 'start': 14, 'end': 17, 'text': 'man'},
#   {'label': 'clinical_event', 'start': 18, 'end': 27, 'text': 'presented'},
#   {'label': 'nonbiological_location',
#    'start': 35,
#    'end': 43,
#    'text': 'hospital'},
#   {'label': 'sign_symptom', 'start': 72, 'end': 78, 'text': 'bruits'},
#   {'label': 'biological_structure',
#    'start': 59,
#    'end': 71,
#    'text': 'intracranial'},
#   {'label': 'diagnostic_procedure',
#    'start': 102,
#    'end': 125,
#    'text': 'laboratory examinations'},
#   {'label': 'diagnostic_procedure',
#    'start': 84,
#    'end': 97,
#    'text': 'cranial nerve'},
#   {'label': 'lab_value', 'start': 131, 'end': 137, 'text': 'normal'},
#   {'label': 'disease_disorder', 'start': 141, 'end': 145, 'text': 'DVAF'},
#   {'label': 'diagnostic_procedure',
#    'start': 162,
#    'end': 206,
#    'text': 'conventional digital subtraction angiography'},
#   {'label': 'disease_disorder',
#    'start': 237,
#    'end': 252,
#    'text': 'Cognard II DVAF'},
#   {'label': 'biological_structure',
#    'start': 272,
#    'end': 295,
#    'text': 'right hypoglossal canal'},
#   {'label': 'biological_structure', 'start': 297, 'end': 299, 'text': 'HC'},
#   {'label': 'coreference', 'start': 306, 'end': 310, 'text': 'DVAF'},
#   {'label': 'biological_structure',
#    'start': 326,
#    'end': 344,
#    'text': 'meningeal branches'},
#   {'label': 'biological_structure',
#    'start': 352,
#    'end': 391,
#    'text': 'bilateral ascending pharyngeal arteries'},
#   {'label': 'biological_structure',
#    'start': 401,
#    'end': 430,
#    'text': 'right anterior condylar veins'},
#   {'label': 'biological_structure',
#    'start': 442,
#    'end': 459,
#    'text': 'hypoglossal canal'},
#   {'label': 'sign_symptom',
#    'start': 473,
#    'end': 488,
#    'text': 'fistulous point'},
#   {'label': 'detailed_description',
#    'start': 496,
#    'end': 525,
#    'text': 'drained into the jugular vein'},
#   {'label': 'therapeutic_procedure',
#    'start': 527,
#    'end': 549,
#    'text': 'Endovascular treatment'},
#   {'label': 'coreference', 'start': 634, 'end': 639, 'text': 'bruit'},
#   {'label': 'biological_structure',
#    'start': 621,
#    'end': 633,
#    'text': 'intracranial'},
#   {'label': 'detailed_description',
#    'start': 609,
#    'end': 620,
#    'text': 'intolerable'},
#   {'label': 'therapeutic_procedure',
#    'start': 668,
#    'end': 690,
#    'text': 'transarterial approach'},
#   {'label': 'medication',
#    'start': 697,
#    'end': 715,
#    'text': 'general anesthesia'},
#   {'label': 'therapeutic_procedure',
#    'start': 724,
#    'end': 749,
#    'text': 'biplane angiographic unit'},
#   {'label': 'therapeutic_procedure',
#    'start': 751,
#    'end': 778,
#    'text': 'Standard coaxial techniques'},
#   {'label': 'therapeutic_procedure',
#    'start': 794,
#    'end': 822,
#    'text': 'guide catheter was navigated'},
#   {'label': 'biological_structure',
#    'start': 832,
#    'end': 869,
#    'text': 'left ascendingtrawt pharyngeal artery'},
#   {'label': 'therapeutic_procedure',
#    'start': 1019,
#    'end': 1044,
#    'text': 'microcatheter was flushed'},
#   {'label': 'volume', 'start': 1050, 'end': 1055, 'text': '10 mL'},
#   {'label': 'biological_structure',
#    'start': 1059,
#    'end': 1072,
#    'text': 'normal saline'},
#   {'label': 'therapeutic_procedure',
#    'start': 871,
#    'end': 935,
#    'text': 'Marathon flow directed catheter (eV3) was subsequently navigated'},
#   {'label': 'sign_symptom', 'start': 1006, 'end': 1013, 'text': 'fistula'},
#   {'label': 'diagnostic_procedure',
#    'start': 1407,
#    'end': 1416,
#    'text': 'angiogram'},
#   {'label': 'detailed_description',
#    'start': 1397,
#    'end': 1406,
#    'text': 'follow-up'},
#   {'label': 'sign_symptom',
#    'start': 1427,
#    'end': 1441,
#    'text': 'residual shunt'},
#   {'label': 'biological_structure',
#    'start': 1459,
#    'end': 1471,
#    'text': 'intracranial'},
#   {'label': 'sign_symptom', 'start': 1472, 'end': 1478, 'text': 'bruits'},
#   {'label': 'dosage', 'start': 1550, 'end': 1555, 'text': '10 mg'},
#   {'label': 'medication', 'start': 1556, 'end': 1569, 'text': 'dexamethasone'},
#   {'label': 'administration',
#    'start': 1574,
#    'end': 1596,
#    'text': 'intravenously injected'},
#   {'label': 'duration', 'start': 1601, 'end': 1611, 'text': 'three days'},
#   {'label': 'date',
#    'start': 1620,
#    'end': 1659,
#    'text': 'second day after endovascular treatment'},
#   {'label': 'sign_symptom',
#    'start': 1688,
#    'end': 1716,
#    'text': 'difficulty moving his tongue'},
#   {'label': 'diagnostic_procedure',
#    'start': 1744,
#    'end': 1755,
#    'text': 'examination'},
#   {'label': 'biological_structure',
#    'start': 1730,
#    'end': 1743,
#    'text': 'Cranial nerve'},
#   {'label': 'sign_symptom',
#    'start': 1783,
#    'end': 1812,
#    'text': 'right hypoglossal nerve palsy'},
#   {'label': 'clinical_event',
#    'start': 1830,
#    'end': 1840,
#    'text': 'discharged'},
#   {'label': 'nonbiological_location',
#    'start': 1850,
#    'end': 1858,
#    'text': 'hospital'},
#   {'label': 'date',
#    'start': 1859,
#    'end': 1884,
#    'text': 'four days after treatment'},
#   {'label': 'medication',
#    'start': 1893,
#    'end': 1921,
#    'text': 'continuative pharmacotherapy'},
#   {'label': 'date',
#    'start': 1926,
#    'end': 1946,
#    'text': 'two months follow-up'},
#   {'label': 'sign_symptom', 'start': 2005, 'end': 2014, 'text': 'dysphagia'},
#   {'label': 'sign_symptom', 'start': 2036, 'end': 2046, 'text': 'dysarthria'},
#   {'label': 'sign_symptom', 'start': 2148, 'end': 2159, 'text': 'hemiatrophy'},
#   {'label': 'detailed_description',
#    'start': 2129,
#    'end': 2135,
#    'text': 'marked'},
#   {'label': 'detailed_description',
#    'start': 2136,
#    'end': 2147,
#    'text': 'right-sided'},
#   {'label': 'diagnostic_procedure',
#    'start': 2106,
#    'end': 2123,
#    'text': 'tongue protrusion'},
#   {'label': 'lab_value',
#    'start': 2066,
#    'end': 2098,
#    'text': 'tongue deviated toward the right'},
#   {'label': 'diagnostic_procedure',
#    'start': 2204,
#    'end': 2213,
#    'text': 'examation'},
#   {'label': 'coreference',
#    'start': 2221,
#    'end': 2250,
#    'text': 'right hypoglossal nerve palsy'},
#   {'label': 'date',
#    'start': 2290,
#    'end': 2312,
#    'text': 'three months follow-up'},
#   {'label': 'diagnostic_procedure',
#    'start': 2329,
#    'end': 2350,
#    'text': 'vocal cord evaluation'},
#   {'label': 'subject', 'start': 2357, 'end': 2371, 'text': 'ENT specialist'},
#   {'label': 'nonbiological_location',
#    'start': 2377,
#    'end': 2391,
#    'text': 'local hospital'},
#   {'label': 'sign_symptom', 'start': 2404, 'end': 2413, 'text': 'paralysis'},
#   {'label': 'biological_structure',
#    'start': 2393,
#    'end': 2403,
#    'text': 'Vocal cord'},
#   {'label': 'sign_symptom', 'start': 2470, 'end': 2481, 'text': 'dysfunction'},
#   {'label': 'biological_structure',
#    'start': 2458,
#    'end': 2469,
#    'text': 'vagus nerve'},
#   {'label': 'medication',
#    'start': 2483,
#    'end': 2499,
#    'text': 'Oral Vitamin B12'},
#   {'label': 'therapeutic_procedure',
#    'start': 1096,
#    'end': 1133,
#    'text': 'microcatheter was subsequently filled'},
#   {'label': 'medication',
#    'start': 1139,
#    'end': 1157,
#    'text': 'dimethyl sulfoxide'},
#   {'label': 'therapeutic_procedure',
#    'start': 1183,
#    'end': 1191,
#    'text': 'injected'},
#   {'label': 'medication', 'start': 1166, 'end': 1173, 'text': 'Onyx-18'},
#   {'label': 'duration', 'start': 1197, 'end': 1208, 'text': 'two minutes'},
#   {'label': 'biological_structure',
#    'start': 2190,
#    'end': 2203,
#    'text': 'cranial nerve'},
#   {'label': 'therapeutic_procedure',
#    'start': 1282,
#    'end': 1303,
#    'text': 'injection was stopped'},
#   {'label': 'clinical_event',
#    'start': 2547,
#    'end': 2556,
#    'text': 'follow-up'}]}

# %%
text = example["text"]
tokenized_text = model.data_processor.words_splitter(text)

# %%
token_offsets = []
for idx, token in enumerate(tokenized_text):
    token_offsets.append((token[0], token[1], token[2], idx))

# %%
token_offsets
# Out:
# [('A', 0, 1, 0),
#  ('48-year-old', 2, 13, 1),
#  ('man', 14, 17, 2),
#  ('presented', 18, 27, 3),
#  ('at', 28, 30, 4),
#  ('our', 31, 34, 5),
#  ('hospital', 35, 43, 6),
#  ('complaining', 44, 55, 7),
#  ('of', 56, 58, 8),
#  ('intracranial', 59, 71, 9),
#  ('bruits', 72, 78, 10),
#  ('.', 78, 79, 11),
#  ('The', 80, 83, 12),
#  ('cranial', 84, 91, 13),
#  ('nerve', 92, 97, 14),
#  ('and', 98, 101, 15),
#  ('laboratory', 102, 112, 16),
#  ('examinations', 113, 125, 17),
#  ('were', 126, 130, 18),
#  ('normal', 131, 137, 19),
#  ('.', 137, 138, 20),
#  ('A', 139, 140, 21),
#  ('DVAF', 141, 145, 22),
#  ('was', 146, 149, 23),
#  ('considered', 150, 160, 24),
#  (',', 160, 161, 25),
#  ('conventional', 162, 174, 26),
#  ('digital', 175, 182, 27),
#  ('subtraction', 183, 194, 28),
#  ('angiography', 195, 206, 29),
#  ('was', 207, 210, 30),
#  ('performed', 211, 220, 31),
#  (',', 220, 221, 32),
#  ('which', 222, 227, 33),
#  ('showed', 228, 234, 34),
#  ('a', 235, 236, 35),
#  ('Cognard', 237, 244, 36),
#  ('II', 245, 247, 37),
#  ('DVAF', 248, 252, 38),
#  ('in', 253, 255, 39),
#  ('the', 256, 259, 40),
#  ('location', 260, 268, 41),
#  ('of', 269, 271, 42),
#  ('right', 272, 277, 43),
#  ('hypoglossal', 278, 289, 44),
#  ('canal', 290, 295, 45),
#  ('(', 296, 297, 46),
#  ('HC', 297, 299, 47),
#  (')', 299, 300, 48),
#  ('.', 300, 301, 49),
#  ('The', 302, 305, 50),
#  ('DVAF', 306, 310, 51),
#  ('was', 311, 314, 52),
#  ('fed', 315, 318, 53),
#  ('by', 319, 321, 54),
#  ('the', 322, 325, 55),
#  ('meningeal', 326, 335, 56),
#  ('branches', 336, 344, 57),
#  ('of', 345, 347, 58),
#  ('the', 348, 351, 59),
#  ('bilateral', 352, 361, 60),
#  ('ascending', 362, 371, 61),
#  ('pharyngeal', 372, 382, 62),
#  ('arteries', 383, 391, 63),
#  (',', 391, 392, 64),
#  ('and', 393, 396, 65),
#  ('the', 397, 400, 66),
#  ('right', 401, 406, 67),
#  ('anterior', 407, 415, 68),
#  ('condylar', 416, 424, 69),
#  ('veins', 425, 430, 70),
#  ('within', 431, 437, 71),
#  ('the', 438, 441, 72),
#  ('hypoglossal', 442, 453, 73),
#  ('canal', 454, 459, 74),
#  ('that', 460, 464, 75),
#  ('was', 465, 468, 76),
#  ('the', 469, 472, 77),
#  ('fistulous', 473, 482, 78),
#  ('point', 483, 488, 79),
#  ('mainly', 489, 495, 80),
#  ('drained', 496, 503, 81),
#  ('into', 504, 508, 82),
#  ('the', 509, 512, 83),
#  ('jugular', 513, 520, 84),
#  ('vein', 521, 525, 85),
#  ('.', 525, 526, 86),
#  ('Endovascular', 527, 539, 87),
#  ('treatment', 540, 549, 88),
#  ('was', 550, 553, 89),
#  ('insisted', 554, 562, 90),
#  ('upon', 563, 567, 91),
#  ('by', 568, 570, 92),
#  ('the', 571, 574, 93),
#  ('patient', 575, 582, 94),
#  ('because', 583, 590, 95),
#  ('of', 591, 593, 96),
#  ('the', 594, 597, 97),
#  ('associated', 598, 608, 98),
#  ('intolerable', 609, 620, 99),
#  ('intracranial', 621, 633, 100),
#  ('bruit', 634, 639, 101),
#  ('.', 639, 640, 102),
#  ('Treatment', 641, 650, 103),
#  ('was', 651, 654, 104),
#  ('performed', 655, 664, 105),
#  ('by', 665, 667, 106),
#  ('transarterial', 668, 681, 107),
#  ('approach', 682, 690, 108),
#  ('under', 691, 696, 109),
#  ('general', 697, 704, 110),
#  ('anesthesia', 705, 715, 111),
#  ('using', 716, 721, 112),
#  ('a', 722, 723, 113),
#  ('biplane', 724, 731, 114),
#  ('angiographic', 732, 744, 115),
#  ('unit', 745, 749, 116),
#  ('.', 749, 750, 117),
#  ('Standard', 751, 759, 118),
#  ('coaxial', 760, 767, 119),
#  ('techniques', 768, 778, 120),
#  ('were', 779, 783, 121),
#  ('used', 784, 788, 122),
#  ('.', 788, 789, 123),
#  ('The', 790, 793, 124),
#  ('guide', 794, 799, 125),
#  ('catheter', 800, 808, 126),
#  ('was', 809, 812, 127),
#  ('navigated', 813, 822, 128),
#  ('into', 823, 827, 129),
#  ('the', 828, 831, 130),
#  ('left', 832, 836, 131),
#  ('ascendingtrawt', 837, 851, 132),
#  ('pharyngeal', 852, 862, 133),
#  ('artery', 863, 869, 134),
#  ('.', 869, 870, 135),
#  ('Marathon', 871, 879, 136),
#  ('flow', 880, 884, 137),
#  ('directed', 885, 893, 138),
#  ('catheter', 894, 902, 139),
#  ('(', 903, 904, 140),
#  ('eV3', 904, 907, 141),
#  (')', 907, 908, 142),
#  ('was', 909, 912, 143),
#  ('subsequently', 913, 925, 144),
#  ('navigated', 926, 935, 145),
#  ('over', 936, 940, 146),
#  ('a', 941, 942, 147),
#  ('Mirage', 943, 949, 148),
#  ('.', 949, 950, 149),
#  ('008', 950, 953, 150),
#  ('microwire', 954, 963, 151),
#  ('(', 964, 965, 152),
#  ('eV3', 965, 968, 153),
#  (')', 968, 969, 154),
#  ('to', 970, 972, 155),
#  ('reach', 973, 978, 156),
#  ('as', 979, 981, 157),
#  ('near', 982, 986, 158),
#  ('as', 987, 989, 159),
#  ('possible', 990, 998, 160),
#  ('to', 999, 1001, 161),
#  ('the', 1002, 1005, 162),
#  ('fistula', 1006, 1013, 163),
#  ('.', 1013, 1014, 164),
#  ('The', 1015, 1018, 165),
#  ('microcatheter', 1019, 1032, 166),
#  ('was', 1033, 1036, 167),
#  ('flushed', 1037, 1044, 168),
#  ('with', 1045, 1049, 169),
#  ('10', 1050, 1052, 170),
#  ('mL', 1053, 1055, 171),
#  ('of', 1056, 1058, 172),
#  ('normal', 1059, 1065, 173),
#  ('saline', 1066, 1072, 174),
#  ('.', 1072, 1073, 175),
#  ('The', 1074, 1077, 176),
#  ('dead', 1078, 1082, 177),
#  ('space', 1083, 1088, 178),
#  ('of', 1089, 1091, 179),
#  ('the', 1092, 1095, 180),
#  ('microcatheter', 1096, 1109, 181),
#  ('was', 1110, 1113, 182),
#  ('subsequently', 1114, 1126, 183),
#  ('filled', 1127, 1133, 184),
#  ('with', 1134, 1138, 185),
#  ('dimethyl', 1139, 1147, 186),
#  ('sulfoxide', 1148, 1157, 187),
#  ('(', 1158, 1159, 188),
#  ('DMSO', 1159, 1163, 189),
#  (')', 1163, 1164, 190),
#  ('.', 1164, 1165, 191),
#  ('Onyx-18', 1166, 1173, 192),
#  ('was', 1174, 1177, 193),
#  ('then', 1178, 1182, 194),
#  ('injected', 1183, 1191, 195),
#  ('over', 1192, 1196, 196),
#  ('two', 1197, 1200, 197),
#  ('minutes', 1201, 1208, 198),
#  ('to', 1209, 1211, 199),
#  ('fill', 1212, 1216, 200),
#  ('the', 1217, 1220, 201),
#  ('microcatheter', 1221, 1234, 202),
#  ('and', 1235, 1238, 203),
#  ('to', 1239, 1241, 204),
#  ('replace', 1242, 1249, 205),
#  ('the', 1250, 1253, 206),
#  ('DMSO', 1254, 1258, 207),
#  ('in', 1259, 1261, 208),
#  ('the', 1262, 1265, 209),
#  ('dead', 1266, 1270, 210),
#  ('space', 1271, 1276, 211),
#  ('.', 1276, 1277, 212),
#  ('The', 1278, 1281, 213),
#  ('injection', 1282, 1291, 214),
#  ('was', 1292, 1295, 215),
#  ('stopped', 1296, 1303, 216),
#  ('until', 1304, 1309, 217),
#  ('unwanted', 1310, 1318, 218),
#  ('flow', 1319, 1323, 219),
#  ('into', 1324, 1328, 220),
#  ('branches', 1329, 1337, 221),
#  ('of', 1338, 1340, 222),
#  ('the', 1341, 1344, 223),
#  ('right', 1345, 1350, 224),
#  ('ascending', 1351, 1360, 225),
#  ('pharyngeal', 1361, 1371, 226),
#  ('artery', 1372, 1378, 227),
#  ('was', 1379, 1382, 228),
#  ('observed', 1383, 1391, 229),
#  ('.', 1391, 1392, 230),
#  ('The', 1393, 1396, 231),
#  ('follow-up', 1397, 1406, 232),
#  ('angiogram', 1407, 1416, 233),
#  ('showed', 1417, 1423, 234),
#  ('no', 1424, 1426, 235),
#  ('residual', 1427, 1435, 236),
#  ('shunt', 1436, 1441, 237),
#  ('(', 1442, 1443, 238),
#  ('Figure', 1443, 1449, 239),
#  ('\u200b', 1450, 1451, 240),
#  ('1', 1451, 1452, 241),
#  (')', 1452, 1453, 242),
#  ('.', 1453, 1454, 243),
#  ('The', 1455, 1458, 244),
#  ('intracranial', 1459, 1471, 245),
#  ('bruits', 1472, 1478, 246),
#  ('disappeared', 1479, 1490, 247),
#  ('immediately', 1491, 1502, 248),
#  ('after', 1503, 1508, 249),
#  ('the', 1509, 1512, 250),
#  ('operation', 1513, 1522, 251),
#  ('.', 1522, 1523, 252),
#  ('For', 1524, 1527, 253),
#  ('the', 1528, 1531, 254),
#  ('toxicity', 1532, 1540, 255),
#  ('of', 1541, 1543, 256),
#  ('DMSO', 1544, 1548, 257),
#  (',', 1548, 1549, 258),
#  ('10', 1550, 1552, 259),
#  ('mg', 1553, 1555, 260),
#  ('dexamethasone', 1556, 1569, 261),
#  ('was', 1570, 1573, 262),
#  ('intravenously', 1574, 1587, 263),
#  ('injected', 1588, 1596, 264),
#  ('for', 1597, 1600, 265),
#  ('three', 1601, 1606, 266),
#  ('days', 1607, 1611, 267),
#  ('.', 1611, 1612, 268),
#  ('On', 1613, 1615, 269),
#  ('the', 1616, 1619, 270),
#  ('second', 1620, 1626, 271),
#  ('day', 1627, 1630, 272),
#  ('after', 1631, 1636, 273),
#  ('endovascular', 1637, 1649, 274),
#  ('treatment', 1650, 1659, 275),
#  (',', 1659, 1660, 276),
#  ('the', 1661, 1664, 277),
#  ('patient', 1665, 1672, 278),
#  ('complainted', 1673, 1684, 279),
#  ('of', 1685, 1687, 280),
#  ('difficulty', 1688, 1698, 281),
#  ('moving', 1699, 1705, 282),
#  ('his', 1706, 1709, 283),
#  ('tongue', 1710, 1716, 284),
#  ('to', 1717, 1719, 285),
#  ('the', 1720, 1723, 286),
#  ('left', 1724, 1728, 287),
#  ('.', 1728, 1729, 288),
#  ('Cranial', 1730, 1737, 289),
#  ('nerve', 1738, 1743, 290),
#  ('examination', 1744, 1755, 291),
#  ('was', 1756, 1759, 292),
#  ('only', 1760, 1764, 293),
#  ('significant', 1765, 1776, 294),
#  ('for', 1777, 1780, 295),
#  ('a', 1781, 1782, 296),
#  ('right', 1783, 1788, 297),
#  ('hypoglossal', 1789, 1800, 298),
#  ('nerve', 1801, 1806, 299),
#  ('palsy', 1807, 1812, 300),
#  ('.', 1812, 1813, 301),
#  ('The', 1814, 1817, 302),
#  ('patient', 1818, 1825, 303),
#  ('was', 1826, 1829, 304),
#  ('discharged', 1830, 1840, 305),
#  ('from', 1841, 1845, 306),
#  ('our', 1846, 1849, 307),
#  ('hospital', 1850, 1858, 308),
#  ('four', 1859, 1863, 309),
#  ('days', 1864, 1868, 310),
#  ('after', 1869, 1874, 311),
#  ('treatment', 1875, 1884, 312),
#  ('without', 1885, 1892, 313),
#  ('continuative', 1893, 1905, 314),
#  ('pharmacotherapy', 1906, 1921, 315),
#  ('.', 1921, 1922, 316),
#  ('At', 1923, 1925, 317),
#  ('two', 1926, 1929, 318),
#  ('months', 1930, 1936, 319),
#  ('follow-up', 1937, 1946, 320),
#  (',', 1946, 1947, 321),
#  ('the', 1948, 1951, 322),
#  ('patient', 1952, 1959, 323),
#  ("'", 1959, 1960, 324),
#  ('s', 1960, 1961, 325),
#  ('main', 1962, 1966, 326),
#  ('complaint', 1967, 1976, 327),
#  ('were', 1977, 1981, 328),
#  ('difficulty', 1982, 1992, 329),
#  ('swallowing', 1993, 2003, 330),
#  ('(', 2004, 2005, 331),
#  ('dysphagia', 2005, 2014, 332),
#  (')', 2014, 2015, 333),
#  ('and', 2016, 2019, 334),
#  ('slurred', 2020, 2027, 335),
#  ('speech', 2028, 2034, 336),
#  ('(', 2035, 2036, 337),
#  ('dysarthria', 2036, 2046, 338),
#  (')', 2046, 2047, 339),
#  ('.', 2047, 2048, 340),
#  ('In', 2049, 2051, 341),
#  ('addition', 2052, 2060, 342),
#  (',', 2060, 2061, 343),
#  ('his', 2062, 2065, 344),
#  ('tongue', 2066, 2072, 345),
#  ('deviated', 2073, 2081, 346),
#  ('toward', 2082, 2088, 347),
#  ('the', 2089, 2092, 348),
#  ('right', 2093, 2098, 349),
#  ('during', 2099, 2105, 350),
#  ('tongue', 2106, 2112, 351),
#  ('protrusion', 2113, 2123, 352),
#  (',', 2123, 2124, 353),
#  ('and', 2125, 2128, 354),
#  ('marked', 2129, 2135, 355),
#  ('right-sided', 2136, 2147, 356),
#  ('hemiatrophy', 2148, 2159, 357),
#  ('was', 2160, 2163, 358),
#  ('observed', 2164, 2172, 359),
#  ('(', 2173, 2174, 360),
#  ('Figure', 2174, 2180, 361),
#  ('\u200b', 2181, 2182, 362),
#  ('2', 2182, 2183, 363),
#  (')', 2183, 2184, 364),
#  ('.', 2184, 2185, 365),
#  ('The', 2186, 2189, 366),
#  ('cranial', 2190, 2197, 367),
#  ('nerve', 2198, 2203, 368),
#  ('examation', 2204, 2213, 369),
#  ('showed', 2214, 2220, 370),
#  ('right', 2221, 2226, 371),
#  ('hypoglossal', 2227, 2238, 372),
#  ('nerve', 2239, 2244, 373),
#  ('palsy', 2245, 2250, 374),
#  ('persisted', 2251, 2260, 375),
#  ('.', 2260, 2261, 376),
#  ('We', 2262, 2264, 377),
#  ('telephone', 2265, 2274, 378),
#  ('the', 2275, 2278, 379),
#  ('patient', 2279, 2286, 380),
#  ('at', 2287, 2289, 381),
#  ('three', 2290, 2295, 382),
#  ('months', 2296, 2302, 383),
#  ('follow-up', 2303, 2312, 384),
#  ('and', 2313, 2316, 385),
#  ('requested', 2317, 2326, 386),
#  ('a', 2327, 2328, 387),
#  ('vocal', 2329, 2334, 388),
#  ('cord', 2335, 2339, 389),
#  ('evaluation', 2340, 2350, 390),
#  ('by', 2351, 2353, 391),
#  ('an', 2354, 2356, 392),
#  ('ENT', 2357, 2360, 393),
#  ('specialist', 2361, 2371, 394),
#  ('in', 2372, 2374, 395),
#  ('a', 2375, 2376, 396),
#  ('local', 2377, 2382, 397),
#  ('hospital', 2383, 2391, 398),
#  ('.', 2391, 2392, 399),
#  ('Vocal', 2393, 2398, 400),
#  ('cord', 2399, 2403, 401),
#  ('paralysis', 2404, 2413, 402),
#  ('was', 2414, 2417, 403),
#  ('not', 2418, 2421, 404),
#  ('found', 2422, 2427, 405),
#  (',', 2427, 2428, 406),
#  ('and', 2429, 2432, 407),
#  ('there', 2433, 2438, 408),
#  ('was', 2439, 2442, 409),
#  ('no', 2443, 2445, 410),
#  ('evidence', 2446, 2454, 411),
#  ('of', 2455, 2457, 412),
#  ('vagus', 2458, 2463, 413),
#  ('nerve', 2464, 2469, 414),
#  ('dysfunction', 2470, 2481, 415),
#  ('.', 2481, 2482, 416),
#  ('Oral', 2483, 2487, 417),
#  ('Vitamin', 2488, 2495, 418),
#  ('B12', 2496, 2499, 419),
#  ('was', 2500, 2503, 420),
#  ('used', 2504, 2508, 421),
#  ('and', 2509, 2512, 422),
#  ('his', 2513, 2516, 423),
#  ('prognosis', 2517, 2526, 424),
#  ('was', 2527, 2530, 425),
#  ('still', 2531, 2536, 426),
#  ('at', 2537, 2539, 427),
#  ('a', 2540, 2541, 428),
#  ('long', 2542, 2546, 429),
#  ('follow-up', 2547, 2556, 430),
#  ('.', 2556, 2557, 431)]

# %%
gliner_entities = []
entities = example["entities"]
for entity in entities:
    entity_start = entity["start"]
    entity_end = entity["end"]
    entity_label = entity["label"]
    entity_tokens = []
    for i, (token_text, token_start, token_end, idx) in enumerate(token_offsets):
        if token_start >= entity_start and token_end <= entity_end:
            entity_tokens.append((token_text, idx))
    if entity_tokens:
        gliner_entities.append([
            entity_tokens[0][1],
            entity_tokens[-1][1],
            entity_label.replace("_", " ").capitalize()
        ])

# %%
sorted(gliner_entities, key=lambda x: x[0])
# Out:
# [[1, 1, 'Age'],
#  [2, 2, 'Sex'],
#  [3, 3, 'Clinical event'],
#  [6, 6, 'Nonbiological location'],
#  [9, 9, 'Biological structure'],
#  [10, 10, 'Sign symptom'],
#  [13, 14, 'Diagnostic procedure'],
#  [16, 17, 'Diagnostic procedure'],
#  [19, 19, 'Lab value'],
#  [22, 22, 'Disease disorder'],
#  [26, 29, 'Diagnostic procedure'],
#  [36, 38, 'Disease disorder'],
#  [43, 45, 'Biological structure'],
#  [47, 47, 'Biological structure'],
#  [51, 51, 'Coreference'],
#  [56, 57, 'Biological structure'],
#  [60, 63, 'Biological structure'],
#  [67, 70, 'Biological structure'],
#  [73, 74, 'Biological structure'],
#  [78, 79, 'Sign symptom'],
#  [81, 85, 'Detailed description'],
#  [87, 88, 'Therapeutic procedure'],
#  [99, 99, 'Detailed description'],
#  [100, 100, 'Biological structure'],
#  [101, 101, 'Coreference'],
#  [107, 108, 'Therapeutic procedure'],
#  [110, 111, 'Medication'],
#  [114, 116, 'Therapeutic procedure'],
#  [118, 120, 'Therapeutic procedure'],
#  [125, 128, 'Therapeutic procedure'],
#  [131, 134, 'Biological structure'],
#  [136, 145, 'Therapeutic procedure'],
#  [163, 163, 'Sign symptom'],
#  [166, 168, 'Therapeutic procedure'],
#  [170, 171, 'Volume'],
#  [173, 174, 'Biological structure'],
#  [181, 184, 'Therapeutic procedure'],
#  [186, 187, 'Medication'],
#  [192, 192, 'Medication'],
#  [195, 195, 'Therapeutic procedure'],
#  [197, 198, 'Duration'],
#  [214, 216, 'Therapeutic procedure'],
#  [232, 232, 'Detailed description'],
#  [233, 233, 'Diagnostic procedure'],
#  [236, 237, 'Sign symptom'],
#  [245, 245, 'Biological structure'],
#  [246, 246, 'Sign symptom'],
#  [259, 260, 'Dosage'],
#  [261, 261, 'Medication'],
#  [263, 264, 'Administration'],
#  [266, 267, 'Duration'],
#  [271, 275, 'Date'],
#  [281, 284, 'Sign symptom'],
#  [289, 290, 'Biological structure'],
#  [291, 291, 'Diagnostic procedure'],
#  [297, 300, 'Sign symptom'],
#  [305, 305, 'Clinical event'],
#  [308, 308, 'Nonbiological location'],
#  [309, 312, 'Date'],
#  [314, 315, 'Medication'],
#  [318, 320, 'Date'],
#  [332, 332, 'Sign symptom'],
#  [338, 338, 'Sign symptom'],
#  [345, 349, 'Lab value'],
#  [351, 352, 'Diagnostic procedure'],
#  [355, 355, 'Detailed description'],
#  [356, 356, 'Detailed description'],
#  [357, 357, 'Sign symptom'],
#  [367, 368, 'Biological structure'],
#  [369, 369, 'Diagnostic procedure'],
#  [371, 374, 'Coreference'],
#  [382, 384, 'Date'],
#  [388, 390, 'Diagnostic procedure'],
#  [393, 394, 'Subject'],
#  [397, 398, 'Nonbiological location'],
#  [400, 401, 'Biological structure'],
#  [402, 402, 'Sign symptom'],
#  [413, 414, 'Biological structure'],
#  [415, 415, 'Sign symptom'],
#  [417, 419, 'Medication'],
#  [430, 430, 'Clinical event']]
